# %% [markdown]
# # MELON TOP100 CROWLING

# %% [markdown]
# # 검색을 크롤링하자

# %%
import re

import requests

from bs4 import BeautifulSoup

import json

import time

# %%
singers = [ '신성우', '먼데이 키즈', '휘성', '버즈', '이승철', '디셈버', 'V.O.S', '김동률', '성시경', '바비 킴', '부활', '토이', 'SG워너비', '임창정', 'YB', '브라운 아이즈', '이현', 'Homme', '환희', '버스커버스커', '김경호', '케이윌', '김연우', '김범수', '이적', '먼데이 키즈', '허각', '플라이 투 더 스카이', '나윤권', '이승기', '이기찬', '김태우', '엠씨 더 맥스', '박완규', '포맨', '신용재', '바이브', '윤종신', '이지훈', '정준일', '박효신', '이승철', ' 더 크로스', '팀', '멜로망스', '어반자카바', '볼빨간사춘기', '헤이즈', '황치열', '아이유', '김나영', '10cm' , '유재하', '김광석', '라디']
len(singers)
# Out:
# 55

# %%
def lyrics(song_dict,song_list,second=1):
    songs_input_dict = {}
    #print(type(songs_input_dict))
    for title in song_list:
        print('title: '+ title)
        ly = []
        url = song_dict[title]
        time.sleep(10)
        html = requests.get(url).text
        soup = BeautifulSoup(html, 'html.parser')
        try:
            for i in soup.select('body .lyric')[0].stripped_strings:
                ly.append(i)
        except IndexError:
            pass
        songs_input_dict[title] = ly
        
    return  songs_input_dict

# %%
def melon_chart():
    song_list=[]
    song_dict={}
    chart_url = 'http://www.melon.com/chart/index.htm'
    html = requests.get(chart_url).text
    soup = BeautifulSoup(html, 'html.parser')
    for idx, song_tag in enumerate(soup.select('#tb_list a[href*=playSong]'), 1):
        menu_id, song_id = re.findall(r'\d+', song_tag['href'])
        song_url = 'http://www.melon.com/song/detail.htm?songId=' + song_id
        song_list.append(song_tag.text)
        song_dict[song_tag.text] = song_url
        #print(idx, song_tag.text, '||', song_url)
    songs_input_dict = lyrics(song_dict,song_list)
    return  songs_input_dict

# %%
def melon_search(q):
    url='http://www.melon.com/search/keyword/index.json'
    params = {
        'jscallback':'jQuery19109732440867001123_1510148061857',
        'query': q,
    }
    html = requests.get(url,params=params).text
    json_string = html.replace(params['jscallback'] + '(', '').replace(');','')
    result_dict = json.loads(json_string)
    song_dict = {}
    song_list = []
    print('name : '+q)
    if 'SONGCONTENTS' not in result_dict:
        print ('not found')
    else:
        for song in result_dict['SONGCONTENTS']:
            
            url = 'http://www.melon.com/song/detail.htm?songId='+song['SONGID']
            song_list.append(song['SONGNAME'])
            song_dict[song['SONGNAME']] = url

    songs_input_dict = lyrics(song_dict,song_list)
        
    return  song_dict, songs_input_dict

# %% [markdown]
# %%time
# songs_input_dict = melon_chart()

# %%
# %%time
_, song_dict = melon_search('김창완')
# Out:
# name : 김창완
# title: 안녕
# title: 꼬마야
# title: 어머니와 고등어
# title: 개구쟁이
# title: 어머니와 고등어
# title: 젊은 날의 초상
# title: 독백
# title: 시간 (Feat. 고상지)
# title: 너를 업던 기억
# title: 안녕이란 말은 너무 어려워
# title: 산 할아버지
# title: 초야
# title: 당신이 날 불러주기 전에는
# title: 시인과 나
# title: 둘이서
# CPU times: user 708 ms, sys: 16 ms, total: 724 ms
# title: 하루 끝
# title: 이름에게
# title: 이 지금
# title: 너의 의미 (Feat. 김창완)
# title: 사랑이 잘 (With 오혁)
# title: 이런 엔딩
# title: 스물셋
# title: 푸르던
# title: 좋은 날
# title: 나만 몰랐던 이야기
# total: 708
# name : 김나영
# title: 그럴걸
# title: 어떻게 사랑이 그래요 (역도요정 김복면)
# title: 어땠을까
# title: 가끔 내가
# title: 다시 너를
# title: 꺼내본다
# title: 가슴이 말해
# title: 널 미워하지 않길 (Prod. By 하동균)
# title: 흔한 이별
# title: 괜찮다고
# title: 눈물 (Tears)
# title: 바라고 바라고
# title: 어른이 된다는 게
# title: 그럴 리가
# title: 니 말대로
# total: 723
# name : 10cm
# title: 폰서트
# title: HELP
# title: 스토커
# title: pet
# title: Nothing Without You
# title: 애상
# title: 사랑은 은하수 다방에서
# title: Fine Thank You And You?
# title: 봄이 좋냐??
# title: 그게 아니고
# title: 10월의 날씨
# title: 쓰담쓰담
# title: 내 눈에만 보여
# title: 안아줘요
# title: Everything
# total: 738
# Wall time: 2h 14min 27s

# %%
with open('songs_dict_data.txt', 'r') as f:
    songs_dict=json.load(f)
songs_dict.append(song_dict)

# %%
with open('songs_dict_data.txt', 'w') as f:
    json.dump(songs_dict, f)

# %% [markdown]
# # POS TAGGING

# %%
from konlpy.tag import Twitter
twitter=Twitter()

# %%
with open('songs_dict_data.txt', 'r') as f:
    songs_dict=json.load(f)
print(len(songs_dict))
# Out:
# 56

# %%
keys = []
for i in range(len(songs_dict)):
    keys.append(list(songs_dict[i].keys()))

# %%
' '.join(songs_dict[0][keys[0][2]])
# Out:
# '세상을 살아오는 동안에 몇번의 사랑들을 만나게되고 때론 결코 원치 않는 이별들도 해야 했었답니다 하지만 당신만은 내곁에 영원히 두고 싶던 나의 마음은 그저 부질없는 욕심이었나요 아직 알 수 없어요 당신이 떠나가던 그날에 그저 사랑하는 마음하나만으로는 지킬 수 없다는게 세상에 있다는걸 비로소 깨닫게 되었죠 내가 사랑하는 그대여 내게 어두움이 머물면 환한미소 건네주던 당신이 나의곁에 있었다는 사실만으로 이렇게 웃을 수 있는데 나를 떠나가는 그대여 아쉬운 기억들은 여기두고 떠나요 당신의 마음속에 행복만이 가득하기를 이젠 내가 기도할께요 내가 사랑하는 그대여 내게 어두움이 머물면 환한미소 건네주던 당신이 나의곁에 있었다는 사실만으로 이렇게 웃을 수 있는데 나를 떠나가는 그대여 아쉬운 기억들은 여기두고 떠나요 당신의 마음속에 행복만이 가득하기를 이젠 내가 기도할께요'

# %%
keys[-1]
# Out:
# ['개구쟁이',
#  '너를 업던 기억',
#  '안녕',
#  '젊은 날의 초상',
#  '산 할아버지',
#  '안녕이란 말은 너무 어려워',
#  '당신이 날 불러주기 전에는',
#  '초야',
#  '독백',
#  '둘이서',
#  '시간 (Feat. 고상지)',
#  '어머니와 고등어',
#  '시인과 나',
#  '꼬마야']

# %%
words = []
for i, key in enumerate(keys):
    for song in key:
        pos = (twitter.morphs(' '.join( songs_dict[i][song])))
    words += pos

# %%
len(set(words))
# Out:
# 1982

# %%
pos_song = {}
total = 0
for i, key in enumerate(keys):
    for song in key:
        song_main=[]
        print (song, ':' , len(songs_dict[i][song]))
        total += len(songs_dict[i][song])
        for line in songs_dict[i][song]:
            song_main.append(twitter.morphs(line))
        pos_song[song] = song_main
print ('total : ', total)
# Out:
# `친구`라 말할 수 있는 건 : 34
# 사랑한 후에 (2006 Ver.) : 34
# 고여 : 32
# 내일을 향해 : 28
# 사랑한 후에 : 38
# 슬픔이 올때 : 46
# 서시 (2006 Ver.) : 36
# 이연(異緣) : 30
# 노을에 기댄 이유 : 13
# 서시 : 25
# 발자국 : 48
# 사랑해 그리고 기억해 : 1
# 새 살 : 34
# 내 맘 모르지 : 26
# 흩어져 : 49
# 거짓말 하는 법 : 27
# 흉터 : 40
# 하기 싫은 말 : 28
# 그대여 : 38
# 남자야 : 43
# 녹슨 가슴 : 57
# 이런 남자 : 65
# Bye Bye Bye : 36
# 가슴으로 외쳐 (Rap Feat. Rhymer) : 52
# 누군가를 떠나 보낸다는 건 : 36
# 일년이면 : 58
# 안되나요 : 30
# Insomnia (불면증) : 56
# 불치병 (Feat. Masta Wu) : 107
# 다시 만난 날 : 65
# With Me : 57
# 안 되나요.. (부제: 화양연화) : 33
# Special Love : 47
# 결혼까지 생각했어 : 55
# 사랑은 맛있다♡ : 69
# 전할 수 없는 이야기 (부제:시티 오브 엔젤) : 41
# 사랑 그 몹쓸 병 : 40
# Rain Drop (With G.고릴라) : 43
# 가슴 시린 이야기 (Feat. 용준형 Of Beast) : 59
# 너라는 명작 : 59
# My Love (And) : 28
# 은인 : 46
# 가시 : 28
# 가난한 사랑 : 26
# 사랑은 가슴이 시킨다 Part.3 : 37
# 비망록 (스물의노래) : 43
# 남자를 몰라 : 47
# 거짓말 : 31
# 어쩌면... : 57
# 사랑하지 않은 것처럼 : 29
# Monologue : 42
# My Darling (End) : 34
# 나에게로 떠나는 여행 : 38
# 겁쟁이 : 44
# 활주 (`나루토` 여는 노래) : 46
# 말리꽃 : 29
# 서쪽 하늘 : 41
# Never Ending Story : 22
# My Love : 39
# 아마추어 : 43
# 그 사람 : 30
# 잊었니 : 33
# 소리쳐 : 46
# 인연 : 30
# 듣고 있나요 : 53
# 그런 사람 또 없습니다 : 24
# 인연 (드라마 `불새`) : 29
# 사랑 참 어렵다 : 30
# 가슴으로 운다 (Feat. 아이린, 윤미) : 37
# 눈부신 눈물 : 1
# 누구보다 널 사랑해 : 44
# 여자는 나쁜남자를 좋아한다 : 29
# 돌아올순 없나요 : 23
# 네게 줄 수 있는건 오직 사랑뿐 : 23
# 별이될께 : 37
# 별이 될께 : 37
# 배운게 사랑이라 : 46
# 사랑 참... : 27
# She`s Gone : 68
# 기억을 걷다보면 : 44
# 이 노랠 빌려서 (Feat. 이로울 & 아이린) : 43
# 미인 : 44
# 혼자 왔어요 : 39
# Beautiful Life : 53
# 미치겠다 (With V.O.S) : 1
# 눈을 보고 말해요 : 40
# 젊은날 : 39
# 울어 : 56
# 나이젠 : 32
# 보고싶은 날엔.. : 39
# 기다릴게 : 42
# 시한부 : 27
# 큰일이다 : 47
# 매일매일 : 50
# 사랑합니다 : 41
# 이젠 남이야. (Feat. Baby-J Of Jewelry) : 44
# 부디 : 38
# 반쪽 : 48
# 다시 시작해보자 : 41
# 내 사람 : 47
# 감사 : 44
# 동행 : 52
# 기억의 습작 : 36
# 그게 나야 : 27
# 사랑한다는 말 : 42
# 출발 : 41
# 기적 (Duet With 이소은) : 38
# Replay : 42
# 다시 사랑한다 말할까 : 48
# 취중진담 : 57
# 아이처럼 : 37
# 오래된 노래 : 37
# 그대네요 : 43
# 다정하게, 안녕히 : 37
# 희재 : 42
# 너의 모든 순간 : 30
# 좋을텐데 : 40
# 두사람 : 38
# 너에게 : 48
# 내게 오는 길 : 21
# 넌 감동이었어 : 28
# 제주도의 푸른 밤 : 34
# 내일 할 일 : 47
# 거리에서 : 1
# 한번 더 이별 : 46
# 너는 나의 봄이다 : 1
# 안녕 나의 사랑 : 56
# Let Me Say Goodbye : 47
# 일년을 하루같이 : 48
# It`s Alright, It`s Allgood (Feat. 윤미래[T]) : 79
# 가슴앓이 : 41
# 소나무 : 25
# 사랑..그 놈 : 35
# 오직 그대만 : 56
# 고래의 꿈 (Falling In Love Again) (Feat. 김영근) : 33
# 바래다주고 오는길 : 32
# MaMa : 29
# 한잔 더 : 50
# 남자답게 : 1
# 사랑한다 할 수 있기에 : 30
# 러브 레시피 : 52
# 사랑할 수 있을때 (Feat. 정인) : 38
# Never Ending Story : 26
# 생각이나 : 27
# 사랑해서 사랑해서 : 44
# 사랑할수록 : 28
# 아름다운 사실 : 23
# 친구야 너는 아니 : 52
# 추억이면 (異面) : 31
# 비밀 (Special Vocal. 박완규) : 40
# 사랑하고 있다 : 30
# 마지막 콘서트 : 45
# Lonely Night : 38
# 사랑이란건 : 41
# 비와 당신의 이야기 : 17
# 오늘 서울은 하루종일 맑음 (Vocal 윤하) : 41
# 내가 너의 곁에 잠시 살았다는걸 : 34
# 세 사람 (With 성시경) : 56
# 바램 : 20
# 언젠가 우리 다시 만나면 (Feat. 김연우) : 32
# U & I (With Crush & 빈지노) : 71
# 좋은 사람 (Feat. 김형중) : 42
# 인생은 아름다워 (With 다이나믹듀오 & Zion. T & Crush) : 93
# 내가 너의 곁에 잠시 살았다는 걸 : 29
# 그럴때마다 : 38
# 뜨거운 안녕 (Vocal 이지형) : 42
# 그녀가 말했다 (With 권진아) : 31
# 너의 바다에 머무네 (With 김동률) : 40
# Reset (With 이적) : 35
# 아리랑 : 47
# 세글자 : 45
# 살다가 : 40
# 사랑하길 정말 잘했어요 : 25
# 사랑하자 : 37
# 내사람 : 26
# 라라라 : 38
# 해바라기 : 60
# 바람만바람만 : 28
# 한여름날의 꿈 (Feat. 옥주현) : 40
# 죄와벌 : 36
# 내사랑 울보 : 45
# 광 (狂) : 26
# 가시리 : 52
# Timeless : 38
# 소주 한 잔 : 36
# 내가 저지른 사랑 : 36
# 이미 나에게로 : 52
# 소주한잔 : 25
# 또 다시 사랑 : 39
# 그때 또 다시 (Again) : 50
# 나란놈이란 : 27
# 날 닮은 너 : 32
# Love Affair : 34
# 흔한 노래 : 35
# 결혼해줘 : 34
# 오랜만이야 : 47
# 기다리는 이유 : 33
# 슬픈 혼잣말 : 34
# 사랑 Two : 23
# 꿈꾸는 소녀 Two : 29
# 오늘은 : 13
# 흰수염고래 : 29
# 박하사탕 : 26
# 잊을게 : 40
# 나는 나비 (2011 Ver.) : 37
# 나는 나비 : 31
# 너를 보내고 : 29
# 꽃비 : 20
# 가을 우체국 앞에서 : 19
# 잊을께 : 31
# 담배가게 아가씨 : 58
# Dreamer : 45
# 꿈꾸는 소녀 : 23
# 벌써일년 : 39
# 언제나 그랬죠 : 41
# For You : 44
# 가지마 가지마 : 47
# 그녀가 나를 보네... : 37
# 점점 : 33
# With Coffee : 47
# 옛 사랑 (Duet 장혜진) : 42
# 너 때문에 : 34
# 벌써 일년 : 39
# 비오는 압구정 : 27
# 이 노래 : 50
# 너에게 들려주고 싶은 두번째 이야기 : 88
# 떠나지마 : 32
# Talk About Love : 102
# 비가 와요 : 42
# 비가 내려와 : 48
# 사랑했지만 (상감마마 납시오) : 21
# 가슴이 시린 게 : 49
# 슬픔 속에 그댈 지워야만 해 : 37
# 내꺼중에 최고 : 1
# 흘러내려 : 66
# My Love : 24
# 30분전 (Feat. 임정희) : 42
# 날 닮은 너 : 27
# 슬픔속에 그댈 지워야만 해 : 61
# Show Me The Money : 142
# 헤어진 다음날 : 32
# 그대라서 : 49
# It Girl : 42
# 남자니까 웃는거야 : 34
# 너만을 느끼며 : 58
# 사랑이 아냐 : 37
# 딜레마 : 51
# 어디쯤 왔니 : 40
# 울지 말자 : 59
# 이젠 잊기로 해요 : 44
# 밥만 잘 먹더라 : 48
# 나만의 슬픔 : 28
# 너 내게로 와라 : 54
# 슬픔을 참는 세 가지 방법 : 52
# 내겐 전부니까 : 53
# 가로수 그늘 아래 서면 : 43
# 기억속의 먼 그대에게 (팥의 전사 호빵왕자) : 41
# 가슴 아파도 : 29
# 남자답게 : 29
# 사진 (평창의 마스코트 나야나 수호랑, 넌 내게 반했어 반다비) : 49
# 널 붙잡을 노래 (팥의 전사 호빵왕자) : 47
# 내사람 : 43
# 내가 더 아플게 : 28
# 잊지말아요 (팥의 전사 호빵왕자) : 32
# Tomorrow : 37
# 사랑이 아프다 : 50
# 바보가슴 : 29
# 바람이 되어서라도 : 31
# 환희 : 40
# 아프다 : 31
# 정류장 : 26
# 향수 : 32
# 정말로 사랑한다면 : 67
# 동경소녀 : 39
# 꽃송이가 : 47
# 첫사랑 : 37
# 벚꽃 엔딩 : 51
# 처음엔 사랑이란게 : 46
# 잘할 걸 : 35
# 그댈 마주하는건 힘들어 (그마힘) : 52
# 외로움증폭장치 (브래드 드럼 한판 쉬기) : 32
# 그댄 달라요 : 40
# 막걸리나 : 44
# 여수 밤바다 : 30
# 사랑은 타이밍 : 45
# 아름답게 사랑하는 날까지 : 31
# 비정(非情) : 23
# Shout : 50
# 사랑 그 시린 아픔으로 : 19
# 나의 사랑 천상(天上)에서도 : 38
# 슬픈 영혼의 아리아 [엘리제] : 30
# 나를 슬프게 하는 사람들 : 58
# 사랑과 우정 사이 (With 김연우) (피노키오) : 29
# 사랑했지만 : 21
# 대답 없는 너 : 31
# 와인 : 1
# Don`t Be Quiet! : 37
# 이수(離愁) : 34
# 비정 : 23
# 금지된 사랑 : 31
# 촌스럽게 왜 이래 (You Don`t Know Love) : 70
# 말해! 뭐해? : 46
# 어떻게 사랑이 그래요 (바다의 귀염둥이 아기해마) : 44
# 가슴이 뛴다 : 40
# 니가 필요해 (I Need You) : 38
# 러브119 (Feat. MC몽) : 76
# 눈물이 뚝뚝 : 46
# 선물 (Feat. 은지원) : 44
# Love Blossom (러브블러썸) : 84
# 그게 뭐라고 : 76
# 오늘부터 1일 (Day 1) : 53
# 그립고 그립고 그립다 : 35
# Lay Back : 91
# 꽃이 핀다 : 40
# 이러지마 제발 (Please Don`t...) : 41
# 만약에 말야 (화생방실 클레오파트라) (Bonus Track) : 30
# 내가 너의 곁에 잠시 살았다는 걸 (Unplugged Ver.) : 26
# 여전히 아름다운지 : 26
# 가질 수 없는 너  (화생방실 클레오파트라) (Bonus Track) : 28
# 사랑한다는 흔한 말 : 30
# 그럴때마다 : 38
# 나와 같다면 (김장훈) : 27
# 이별택시 : 26
# 세상이 그대를 속일지라도 : 25
# 내가 너의 곁에 잠시 살았다는 걸 : 19
# 사랑.. 그 놈 (화생방실 클레오파트라) : 30
# 이미 넌 고마운 사람 : 23
# 이 밤이 지나면 (화생방실 클레오파트라) (Bonus Track) : 33
# 사랑할수록 (화생방실 클레오파트라) : 26
# 사랑의 시작은 고백에서부터 : 28
# 사랑해요 : 38
# 슬픔보다 더 슬픈 이야기 : 38
# 너에게 간다 : 48
# 바보같은 내게 : 39
# 오직 너만 : 30
# 보고 싶다 : 25
# 끝사랑 : 31
# 슬픔활용법 : 29
# 하루 : 40
# 너의 집 앞에서 : 36
# 제발 : 30
# 그댄 행복에 살텐데 : 39
# 지나간다 : 21
# 빨래 : 44
# 비포 선라이즈 (Duet With 정인) : 32
# 그대랑 : 42
# 매듭 : 35
# 그땐 미처 알지 못했지 (Feat. 하림 On Harmonica) : 1
# 거짓말 거짓말 거짓말 : 34
# 어느 날 (Duet With 김윤아) : 34
# 오래전 그날 : 38
# 같이 걸을까 : 18
# 하늘을 달리다 : 33
# 웃어라 그대 (Smile, My Love) : 51
# 걱정말아요 그대 : 25
# Rain : 31
# 다행이다 : 30
# 그땐 미처 알지 못했지 : 22
# 발자국 : 48
# 사랑해 그리고 기억해 : 1
# 새 살 : 34
# 내 맘 모르지 : 26
# 흩어져 : 49
# 거짓말 하는 법 : 27
# 흉터 : 40
# 하기 싫은 말 : 28
# 그대여 : 38
# 남자야 : 43
# 녹슨 가슴 : 57
# 이런 남자 : 65
# Bye Bye Bye : 36
# 가슴으로 외쳐 (Rap Feat. Rhymer) : 52
# 누군가를 떠나 보낸다는 건 : 36
# 나를 사랑했던 사람아 : 31
# 나를 잊지 말아요 : 44
# I Need You : 75
# 한사람 : 50
# Hello : 43
# 반창고 : 88
# 동네술집 : 39
# 언제나 : 1
# 혼자, 한잔 : 42
# 죽고 싶단 말 밖에 : 29
# 모노드라마 (With 유승우) : 50
# 행복한 나를 (Feat. 존박) : 1
# 향기만 남아 : 38
# 짧은머리 : 43
# 사월의 눈 : 35
# Sea Of Love : 63
# 중력 (Gravity) : 45
# 전화하지 말아요 : 28
# Day By Day : 36
# 구속 : 34
# 습관 : 47
# 너를 너를 너를 : 34
# 그대는 모르죠 (Good-bye) : 27
# 그렇게 됐어 : 41
# 남자답게 : 26
# 취중진담 (Feat. AND) : 51
# Missing You : 43
# 피 (避) : 34
# 가슴 아파도 : 29
# 중독 : 37
# 첫사랑이죠 : 40
# 겁이 나서 : 36
# 남자가 여자를 사랑할 때 : 32
# 기대 : 41
# 멍청이 : 31
# 뒷모습 : 53
# 늦은 후회 : 34
# 동감 (아미노업 CF `편의점` 권상우편) : 41
# 하루의 끝 : 30
# 그런일은 : 37
# 그게 너라고 : 53
# 나였으면 : 31
# 창문을 열어놓고 : 45
# 면사포 : 38
# 하기 힘든 말 : 39
# 결혼해줄래 : 61
# 착한거짓말 : 39
# 사랑이 술을 가르쳐 (Feat. 백찬 From 8eight) : 44
# 나 군대 간다 : 21
# 되돌리다 : 48
# 원하고 원망하죠 : 30
# 연애시대 (Feat. Ra.D) (Narr. 한효주) : 61
# 우리 헤어지자 : 45
# 여행을 떠나요 : 43
# 추억속의 그대 : 42
# 내 여자라니까 : 38
# 삭제 : 42
# 다 줄꺼야 : 32
# 왜 그래 : 42
# 우리 그만 아프자 : 38
# 비가 오는 날엔 : 19
# 미인 (美人) : 29
# Please : 30
# 지금 만나러 가요 : 44
# 세사람 : 29
# 감기 : 21
# 아니기를 : 26
# 비바 내 사랑 : 54
# 사랑도... 이별도... : 39
# 언젠가 누군가 : 25
# 그댄 행복에 살텐데 : 41
# 또 한번 사랑은 가고 : 56
# 이별이 오지 못하게 : 33
# 꿈을 꾸다 : 41
# I Love U Oh Thank U (With MC몽) : 62
# 너 때문에 : 66
# 어머님께 : 66
# Darling U : 53
# 너 하나만 : 45
# 하고싶은 말 : 27
# 봄 여름 가을 겨울 (With 수호) : 78
# High High : 48
# 사랑비 : 60
# 메아리 : 1
# 따라가 : 55
# 빗물이 내려서 : 28
# 내가 야! 하면 넌 예! (Duet With LYN) : 73
# 그대 그대 그대 : 45
# 그대는 눈물겹다 : 35
# 해바라기도 가끔 목이 아프죠 : 38
# 어디에도 : 44
# 그 남잔 말야 : 35
# 가슴아 그만해 : 40
# One Love : 25
# 잠시만 안녕 (Original) : 42
# 사랑은 아프려고 하는 거죠 : 31
# 행복하지 말아요 : 62
# 바라보기 : 24
# 입술의 말 : 34
# 어김없이 : 29
# 백야 : 34
# 그대가 분다 : 34
# After You`ve Gone : 30
# 회상 III : 38
# 사랑하기 전에는 : 33
# 연 (緣) : 29
# 천년의 사랑 : 25
# 영원 (원곡가수 SKY) : 35
# 그녀의 웃음소리 뿐 (Feat. 하림) : 44
# 사랑했어요 (원곡가수 김현식) : 29
# 약속 : 26
# Alone (카우보이 비밥 엔딩) : 36
# Lonely Night : 38
# 눈물없는 이별 : 23
# 하루애 : 37
# 비밀 (원곡가수 부활) : 66
# Lonely Night (원곡가수 부활) : 37
# 고백 : 52
# 안되겠더라 : 40
# My Angel (Feat. 윤후) (MBC `아빠! 어디가?` 윤후 자장가 삽입곡) : 21
# 너 하나야 : 40
# 추억에 살아 (Feat. 이영현) : 34
# 후회한다 : 43
# 울고, 불고… : 63
# 못해 (Feat. 美) : 32
# Baby Baby : 38
# 안아보자 : 40
# 살다가 한번쯤 : 26
# 안녕 나야 : 50
# Say I Love You : 53
# 다시 사랑 할 수 있을까 (Feat. 다비치) : 65
# 청혼하는 거예요 : 52
# 니가 보여 : 40
# 널 사랑한다, 지운다, 또 운다 : 25
# 빌려줄게 : 41
# 이유 : 33
# 제발 : 41
# 니가 빈 자리 : 44
# 언제나 괜찮아 : 58
# 그런 사람 (Duet Ver.) : 30
# 인연 : 43
# 사랑하는 그대여 : 22
# 가수가 된 이유 : 46
# 꿈에 (뜨거운 심장 양철로봇) : 28
# 해줄 수 없는 일 (뜨거운 심장 양철로봇) : 42
# 거리에서 : 50
# 서로의 서로 : 34
# 꼭 한번 만나고 싶다 : 33
# 그 남자 그 여자 (Feat. 장혜진) : 33
# 별이 빛나는 밤에 : 47
# 우리가 다시 만날 날 (연주: 이루마) : 0
# 축가 (Celebrate Love) : 60
# 바래다 주는 길 : 34
# 미워도 다시 한번 (Original Ver.) : 48
# 술이야 : 41
# 좋은 오빠 동생으로만 : 49
# Promise U : 71
# 마누라 : 40
# 미친거니 : 26
# 썸타 (Lil` Something) : 66
# 다시 와주라 : 36
# 사진을 보다가 : 61
# 말꼬리 : 35
# 오르막길 : 41
# 너의 결혼식 : 30
# 나이 : 39
# 지친 하루 : 44
# 내일 할 일 : 46
# 끝 무렵 : 56
# 좋니 (Inst.) : 45
# 오래전 그날 : 38
# 고요 : 33
# 좋니 : 45
# 1월부터 6월까지 : 31
# 천애 : 70
# 나만의 신부 (Remix) : 33
# 왜하늘은 : 31
# 가슴아 미안하다 : 46
# 이별 : 33
# 인형 (Duet. 신혜성) : 43
# 그대와 함께 (너 자신을 알라 소크라테스 & 나를 따르라 김장군) : 29
# 나만의 신부 : 55
# 내 운명 피하고 싶어 : 51
# 왜 하늘은... : 31
# 약속 : 22
# 금지된 사랑 (나를 따르라 김장군) : 23
# 언제라도 : 25
# 미안해요 (나를 따르라 김장군) : 30
# 또 하나의 열매를 바라시며 : 23
# 말꼬리 : 35
# 고백 : 43
# 있잖아 널 사랑해 : 39
# 짝사랑 : 17
# 하루만큼 하루만 더 : 35
# 미안해 : 36
# 너에게 : 64
# 안아줘 : 35
# 그 계절의 우리 : 26
# 고요 : 33
# 새겨울 : 37
# 바램 : 32
# PLASTIC (Feat. 비와이_BewhY) : 80
# 괜찮아 : 17
# 첫 눈 : 56
# 눈의 꽃 : 59
# 기억속의 먼 그대에게 : 33
# 숨 : 38
# Beautiful Tomorrow : 36
# 좋은사람 : 31
# 야생화 : 40
# 바보 : 16
# 동경 : 40
# 안녕 사랑아 : 31
# 해줄 수 없는 일 : 39
# Home : 59
# 사랑한 후에 : 38
# 추억은 사랑을 닮아 : 59
# HAPPY TOGETHER : 55
# Gift : 37
# 말리꽃 : 29
# 서쪽 하늘 : 41
# Never Ending Story : 22
# My Love : 39
# 아마추어 : 43
# 그 사람 : 30
# 잊었니 : 33
# 소리쳐 : 46
# 인연 : 30
# 듣고 있나요 : 53
# 그런 사람 또 없습니다 : 24
# 인연 (드라마 `불새`) : 29
# 사랑 참 어렵다 : 30
# 세상의 중심에서 사랑을 외치다 : 36
# 사랑하니까 : 35
# 이별의 간주곡 : 21
# 백설공주를 사랑한 난장이 : 36
# Love Song : 50
# 네버엔딩 : 42
# 시간이 지나도 : 42
# 희망 : 27
# Don`t Cry : 35
# 난장이가 쏘아 올린 작은 공 : 26
# 하루만 한 번만 : 60
# 당신을 위하여 : 26
# 떠나가요, 떠나지마요 : 32
# 가끔씩 눈물이 나죠 : 30
# 별(別) : 48
# 나쁜 마음을 먹게해 (Ballad Ver.) : 52
# 청혼 (인생 즐기는 네가 챔피언) : 36
# 너의 뒤에서 (리메이크) : 30
# Wish Ur My Love (with J) : 49
# Say Yes : 46
# 사랑한 만큼 : 45
# 한번쯤은 : 54
# Opening Title (파라다이스 Intro) : 12
# 사랑합니다... : 29
# 하루가 길다 : 31
# 파라다이스 (메인 테마) : 60
# 남자답지 못한 말 : 27
# 사랑 참 나쁘다 : 38
# 봄이 되어준 그대 : 32
# 걸작품 : 44
# 나를 사랑하는 그대에게 : 39
# 영화관에서 : 29
# 질투가 좋아 : 43
# 말해줘요 : 52
# 먼지 : 29
# 조심스러운 이유 : 25
# 입맞춤 : 30
# 그 밤 : 22
# 좋아요 : 46
# 부끄럼 : 48
# 우리 잠깐 쉬어갈래요 : 42
# 선물 : 31
# Moonlight : 0
# 나만 안되는 연애 : 61
# 사랑에 빠졌을 때 : 57
# 드림 : 45
# You(=I) : 46
# 심술 : 44
# X Song : 34
# 남이 될 수 있을까 : 43
# 좋다고 말해 : 60
# 반지 : 36
# 처음부터 너와 나 : 49
# 프리지아 : 29
# 초콜릿 : 50
# 우주를 줄게 : 64
# 가리워진 길 : 26
# 싸운날 : 53
# 썸타 (Lil` Something) : 66
# Underwater : 57
# And July (Feat. DEAN, DJ Friz) : 78
# 먹구름 (Feat. nafla) : 58
# 비도 오고 그래서 (Feat. 신용재) : 59
# 내 남자친구가 고맙대 : 91
# 널 너무 모르고 : 53
# 조금만 더 방황하고 (Feat. Crucial Star) : 90
# Round and round (Feat. 한수지) : 48
# 클럽이라도 좀 가 : 88
# 저 별 : 58
# 돌아오지마 (Acoustic Ver.) : 45
# 돌아오지마 (Feat. 용준형 Of 비스트) : 66
# Shut Up & Groove (Feat. DEAN) : 67
# 너와 함께한 시간 속에서 : 30
# 널 위해 배운 이별 (Goodbye...) : 31
# 잠시나마 : 36
# 아버지 : 28
# 봄이라서 (One Spring Day) : 30
# 사랑 그 한마디 (Alone) : 32
# 고해 : 27
# 그리워 그리워서 (이영 Ver.) : 40
# 슬픈 언약식 : 40
# 그대라는 사치 (짐승남 강백호) : 56
# 각 (Angle) : 52
# 매일 듣는 노래 (A Daily Song) : 45
# 같이 가자 (with you) : 29
# 너를 처음 만난 그때 : 34
# 나보다 조금 더 높은 곳에 니가 있을 뿐 : 41
# 너 없이 못 살아 : 51
# 너의 의미 (Feat. 김창완) : 31
# 이런 엔딩 : 26
# 푸르던 : 36
# 팔레트 (Feat. G-DRAGON) : 56
# 마음 : 27
# 스물셋 : 88
# 이 지금 : 39
# 좋은 날 : 42
# 나의 옛날이야기 : 23
# 이름에게 : 35
# 사랑이 잘 (With 오혁) : 58
# 금요일에 만나요 (Feat. 장이정 Of HISTORY) : 39
# 나만 몰랐던 이야기 : 1
# 하루 끝 : 48
# 밤편지 : 27
# 그럴걸 : 36
# 가끔 내가 : 33
# 흔한 이별 : 39
# 니 말대로 : 42
# 괜찮다고 : 38
# 눈물 (Tears) : 38
# 어른이 된다는 게 : 45
# 널 미워하지 않길 (Prod. By 하동균) : 46
# 바라고 바라고 : 37
# 꺼내본다 : 43
# 어떻게 사랑이 그래요 (역도요정 김복면) : 42
# 그럴 리가 : 37
# 가슴이 말해 : 41
# 어땠을까 : 43
# 다시 너를 : 77
# 사랑은 은하수 다방에서 : 1
# 봄이 좋냐?? : 37
# Fine Thank You And You? : 22
# pet : 46
# Nothing Without You : 35
# 스토커 : 38
# 폰서트 : 61
# HELP : 59
# 10월의 날씨 : 37
# 그게 아니고 : 21
# 안아줘요 : 32
# 내 눈에만 보여 : 35
# Everything : 33
# 애상 : 47
# 쓰담쓰담 : 38
# 지난날 : 56
# 그대 내 품에 : 30
# 가리워진 길 : 22
# 내 마음에 비친 내 모습 : 42
# 그대 내품에 : 33
# 우울한 편지 : 21
# 사랑하기 때문에 : 33
# Minuet : 0
# 우리들의 사랑 : 38
# 내마음에 비친 내모습 : 42
# 텅빈 오늘 밤 : 49
# 지난 날 : 61
# 이등병의 편지 : 27
# 흐린 가을 하늘에 편지를 써 : 45
# 너무 아픈 사랑은 사랑이 아니었음을 : 18
# 먼지가 되어 : 31
# 잊어야 한다는 마음으로 : 26
# 바람이 불어오는 곳 : 23
# 서른 즈음에 : 31
# 너무 깊이 생각하지마 : 42
# 사랑했지만 : 21
# 그날들 : 32
# 변해가네 : 50
# 어느 60대 노부부 이야기 : 31
# 거리에서 : 53
# 사랑이라는 이유로 : 12
# I`m In Love : 34
# Lovesome : 50
# 너를 그리다 : 45
# 눈을 보고 말해요 : 53
# 똑같은 날 : 36
# I`m In Love (Piano RMX) : 36
# Happy Birthday : 1
# 엄마 : 54
# 라디오를 크게 켜고 : 22
# 어떤 설레임 : 28
# 여전히 : 35
# 오랜만이죠 (Feat. 신지수) : 50
# Take Out : 51
# 고마워 고마워 : 51
# Couple Song (Feat. Kelley) : 49
# 개구쟁이 : 6
# 너를 업던 기억 : 25
# 안녕 : 24
# 젊은 날의 초상 : 26
# 산 할아버지 : 16
# 당신이 날 불러주기 전에는 : 22
# 초야 : 17
# 독백 : 17
# 둘이서 : 8
# 시간 (Feat. 고상지) : 66
# 어머니와 고등어 : 1
# 시인과 나 : 1
# 꼬마야 : 28
# total :  30914

# %%
len(pos_song.keys())
# Out:
# 736

# %%
with open('input.txt', 'w') as f:
    json.dump(pos_song, f)

# %% [markdown]
# # WORD2VEC

# %%
import gensim
from gensim.models.word2vec import Word2Vec
import sys
import multiprocessing

# %%
cores = multiprocessing.cpu_count()

# %%
input_w2v = []
for i,key in enumerate(keys):
    for song in key:
        input_w2v += pos_song[song]

# %%
# %%time
model = Word2Vec(input_w2v, size=300, workers=cores,sg=1 ,min_count=0)
# Out:
# Wall time: 878 ms

# %%
# %%time
# Train document vectors!
for epoch in range(100):
    model.train(input_w2v,total_examples=model.corpus_count,epochs=100,compute_loss=True)
# Out:
# Wall time: 20min 30s

# %%
len(model.wv.index2word)
# Out:
# 7980

# %%
model.most_similar('달링')
# Out:
# [('마이', 0.9974309206008911),
#  ('Small', 0.7425969839096069),
#  ('How', 0.7386080026626587),
#  ('ears', 0.7372376322746277),
#  ('Hater', 0.7349669337272644),
#  ('Help', 0.7300851345062256),
#  ('wow', 0.7298029661178589),
#  ('air', 0.7264423370361328),
#  ('face', 0.7263816595077515),
#  ('hater', 0.7253179550170898)]

# %%
model.save("Word2vec.model")

# %% [markdown]
# # Word2vec_load

# %%
model = gensim.models.Word2Vec.load("./Word2vec.model")

# %% [markdown]
# # Word2vec_pad

# %%
import numpy as np

# %%
_PAD_ = "_PAD_"  # 빈칸 채우는 심볼
_STA_ = "_STA_"  # 디코드 입력 시퀀스의 시작 심볼
_EOS_ = "_EOS_"  # 디코드 입출력 시퀀스의 종료 심볼
_UNK_ = "_UNK_"  # 사전에 없는 단어를 나타내는 심볼

_PAD_ID_ = 0
_STA_ID_ = 1
_EOS_ID_ = 2
_UNK_ID_ = 3
_PRE_DEFINED_ = [_PAD_ID_, _STA_ID_, _EOS_ID_, _UNK_ID_]

_PRE_DEFINED_dict = {_PAD_:_PAD_ID_, _STA_:_STA_ID_, _EOS_:_EOS_ID_, _UNK_:_UNK_ID_}

# %%
def ly_len(ly):
    cnt = []
    for i in ly:
        cnt.append(len(i))
    try:
        max_cnt = max(cnt)
    except ValueError:
        pass
    arg_max_cnt = np.argmax(cnt)
    return max_cnt,arg_max_cnt

# %%
def max_len_f(songs_dict):
    max_len = []
    for key in list(songs_dict.keys()):
        try:
            max_cnt, arg_max_cnt = ly_len(songs_dict[key])
        except ValueError:
            print(key)
            pass
        max_len.append(max_cnt)
    max_len = max(max_len)
    return max_len+1

# %%
max_len = max_len_f(pos_song)
# Out:
# Moonlight
# 우리가 다시 만날 날 (연주: 이루마)
# Minuet
# 안녕이란 말은 너무 어려워

# %%
del pos_song['우리가 다시 만날 날 (연주: 이루마)']
del pos_song['Minuet']
del pos_song['Moonlight']
del pos_song['안녕이란 말은 너무 어려워']

# %%
def convert_ly_pos_ly(dict_, keys):
    pos_ly_dict={}
    for title in keys:
        ly = dict_[title]
        pos_ly=[]
        for line in ly:
            pos_ly.append(line)
        pos_ly_dict[title] = pos_ly
    return pos_ly_dict

# %%
def padding(seq, max_len, start=None, eos=None):
    if start:
        padded_seq = [_STA_] + seq
    elif eos:
        padded_seq = seq + [_EOS_]
    else:
        padded_seq = seq

    if len(padded_seq) < max_len:
        return padded_seq + ([_PAD_] * (max_len - len(padded_seq)))
    else:
        return padded_seq

# %%
def data_padding(data):
    pos_padding_dict = {}
    for title in list(data.keys()):
        padding_line=[]
        for line in data[title]:
            padding_line.append(padding(line,max_len,True,None))
        pos_padding_dict[title] = padding_line
    return pos_padding_dict

# %%
pos_ly_dict = convert_ly_pos_ly(pos_song, list(pos_song.keys()))

# %%
pos_padding_dict = data_padding(pos_ly_dict)

# %%
with open('input.txt', 'w') as f:
    json.dump(pos_padding_dict, f)

# %%
cores = multiprocessing.cpu_count()

# %% [markdown]
# ## 재학습

# %%
input_w2v = []
for song in keys[-1]:
    input_w2v += pos_padding_dict[song]
for song in keys[-1]:
    input_w2v +=[twitter.morphs(song)]

# %%
model = gensim.models.Word2Vec.load("./Word2vec_pad.model")

# %%
model.build_vocab(input_w2v, update=True)
for epoch in range(100):
    model.train(input_w2v,total_examples=model.corpus_count,epochs=10,compute_loss=True)
# Out:
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay

# %%
input_w2v = []
for song in list(pos_padding_dict.keys()):
    input_w2v += pos_padding_dict[song]

# %%
targets = []
for target in list(pos_padding_dict.keys()):
    targets.append(twitter.morphs(target)+[_EOS_])

# %%
input_w2v +=targets

# %%
len(input_w2v)
# Out:
# 29391

# %%
# %%time
model = Word2Vec(input_w2v, size=300, workers=cores,sg=1 ,min_count=0)
# Out:
# CPU times: user 11.7 s, sys: 20 ms, total: 11.7 s
# Wall time: 1.82 s

# %%
# %%time
# Train document vectors!
for epoch in range(100):
    model.train(input_w2v,total_examples=model.corpus_count,epochs=10,compute_loss=True)
# Out:
# CPU times: user 36min 32s, sys: 2.8 s, total: 36min 35s
# Wall time: 5min 2s

# %%
model.most_similar('_STA_')
# Out:
# [('hfdegfdh', 0.4481930434703827),
#  ('_PAD_', 0.4395582973957062),
#  ('초상', 0.43252941966056824),
#  ('gfg', 0.42725077271461487),
#  ('고등어', 0.40131622552871704),
#  ('고상지', 0.40110209584236145),
#  ('업던', 0.3972132205963135),
#  ('tfgf', 0.39032843708992004),
#  ('시인', 0.38759317994117737),
#  ('지금', 0.3671084940433502)]

# %%
model.most_similar('_EOS_')
# Out:
# [('Blossom', 0.35731345415115356),
#  ('Opening', 0.3526173233985901),
#  ('아빠', 0.34624671936035156),
#  ('MBC', 0.34174853563308716),
#  ('광', 0.34016141295433044),
#  ('이연', 0.338131844997406),
#  ('오브', 0.3354129195213318),
#  ('축가', 0.3317357003688812),
#  ('?`', 0.3290564715862274),
#  ('非情', 0.32634133100509644)]

# %%
model.most_similar('좋아해')
# Out:
# [('좋아했', 0.40165093541145325),
#  ('전화하려', 0.39881622791290283),
#  ('찾죠', 0.3917097747325897),
#  ('걸어가네', 0.3879711329936981),
#  ('쭉', 0.36903831362724304),
#  ('안달', 0.367202490568161),
#  ('속삭이는', 0.3662204146385193),
#  ('알아보고', 0.3656998574733734),
#  ('사소함', 0.3526631295681),
#  ('촌스러운', 0.3514394462108612)]

# %%
model.save("Word2vec_pad.model")
